# %%
import pandas as pd

# %%
natural_gas_df = pd.read_csv('daily_csv.csv')

# %%
natural_gas_df
# Out:
#             Date  Price
# 0     1997-01-07   3.82
# 1     1997-01-08   3.80
# 2     1997-01-09   3.61
# 3     1997-01-10   3.92
# 4     1997-01-13   4.00
# ...          ...    ...
# 5933  2020-08-05   2.23
# 5934  2020-08-06   2.26
# 5935  2020-08-07   2.15
# 5936  2020-08-10   2.18
# 5937  2020-08-11   2.19
#
# [5938 rows x 2 columns]

# %%
oil_df = pd.read_csv('crudeoil.csv')

# %%
oil_df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2000-03-22  27.650000  28.250000  27.250000  27.459999  27.459999
# 1     2000-03-23  27.650000  27.780001  27.160000  27.309999  27.309999
# 2     2000-03-24  27.850000  28.150000  27.549999  27.980000  27.980000
# 3     2000-03-26        NaN        NaN        NaN        NaN        NaN
# 4     2000-03-27  27.650000  28.020000  27.410000  27.730000  27.730000
# ...          ...        ...        ...        ...        ...        ...
# 6239  2020-07-16  40.900002  41.139999  40.520000  40.759998  40.759998
# 6240  2020-07-17  40.740002  40.900002  40.020000  40.570000  40.570000
# 6241  2020-07-19  40.639999  40.650002  40.459999  40.630001  40.630001
# 6242  2020-07-20  40.360001  40.910000  39.830002  40.650002  40.650002
# 6243  2020-07-21  40.840000  42.400002  40.840000  41.759998  41.759998
#
#           Volume
# 0        92302.0
# 1        79373.0
# 2        55693.0
# 3            NaN
# ...

# %%
pip install quandl

# %%
pi
