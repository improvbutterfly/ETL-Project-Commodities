# %%
import yfinance as yf

msft = yf.Ticker("CEO")

# get stock info
print(msft.info)

# get historical market data
hist = msft.history(period="5y")
# Out:
# {'sector': 'Energy', 'fullTimeEmployees': 18425, 'longBusinessSummary': 'CNOOC Limited, an investment holding company, explores for, develops, produces, and sells crude oil and natural gas in offshore China, Canada, the United States, the United Kingdom, Nigeria, Argentina, Indonesia, Uganda, Iraq, Brazil, Guyana, Russia, Australia, and internationally. The company operates through three segments: E&P, Trading Business, and Corporate. It produces offshore crude oil and natural gas primarily in Bohai, the Western South China Sea, the Eastern South China Sea, and the East China Sea in offshore China. The company also holds interests in various oil and gas assets in Asia, Africa, North America, South America, Oceania, and Europe. As of December 31, 2019, it had net proved reserves of approximately 5.18 billion barrels of oil equivalent. In addition, the company is involved in the issuance of bonds; sale and marketing of petroleum and natural gas; and surface exploration and sale of coalbed methane. The company was incorporated in 1999 and is based in Central, Hong Kong. CNOOC Limited is a subsidiary of China National Offshore Oil Corporation.', 'city': 'Central', 'phone': '852 2213 2500', 'country': 'Hong Kong', 'companyOfficers': [], 'website': 'http://www.cnoocltd.com', 'maxAge': 1, 'address1': 'Bank of China Tower', 'fax': '852 2525 9322', 'industry': 'Oil & Gas E&P', 'address2': '65th Floor 1 Garden Road', 'previousClose': 104.52, 'regularMarketOpen': 109, 'twoHundredDayAverage': 108.5446, 'trailingAnnualDividendYield': 0.0007175661, 'payoutRatio': 0.77589995, 'volume24Hr': None, 'regularMarketDayHigh': 109.89, 'navPrice': None, 'averageDailyVolume10Day': 153116, 'totalAssets': None, 'regularMarketPreviousClose': 104.52, 'fiftyDayAverage': 96.35861, 'trailingAnnualDividendRate': 0.075, 'open': 109, 'toCurrency': None, 'averageVolume10days': 153116, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 8.37, 'exDividendDate': 1599004800, 'beta': 1.218354, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 107.62, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 9.530435, 'regularMarketVolume': 117117, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 44561276928, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 129801, 'priceToSalesTrailing12Months': None, 'dayLow': 107.62, 'ask': 109.62, 'ytdReturn': None, 'askSize': 1000, 'volume': 117117, 'fiftyTwoWeekHigh': 181.13, 'forwardPE': 10.448046, 'fromCurrency': None, 'fiveYearAvgDividendYield': 5.26, 'fiftyTwoWeekLow': 81.11, 'bid': 109.41, 'tradeable': False, 'dividendYield': 0.0801, 'bidSize': 800, 'dayHigh': 109.89, 'exchange': 'NYQ', 'shortName': 'CNOOC Limited', 'longName': 'CNOOC Limited', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EST', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-18000000', 'quoteType': 'EQUITY', 'symbol': 'CEO', 'messageBoardId': 'finmb_1038362', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': None, 'beta3Year': None, 'profitMargins': 0.2074, 'enterpriseToEbitda': None, '52WeekChange': -0.33675992, 'morningStarRiskRating': None, 'forwardEps': 10.49, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 446475008, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 134.8, 'sharesShort': 225652, 'sharesPercentSharesOut': 0.0005, 'fundFamily': None, 'lastFiscalYearEnd': 1577750400, 'heldPercentInstitutions': 0.02103, 'netIncomeToCommon': None, 'trailingEps': 11.5, 'lastDividendValue': 2.581, 'SandP52WeekChange': 0.14834523, 'priceToBook': 0.81305635, 'heldPercentInsiders': 0, 'nextFiscalYearEnd': 1640908800, 'mostRecentQuarter': 1593475200, 'shortRatio': 1.77, 'sharesShortPreviousMonthDate': 1600128000, 'floatShares': 158730636, 'enterpriseValue': 46665519104, 'threeYearAverageReturn': None, 'lastSplitDate': None, 'lastSplitFactor': None, 'legalType': None, 'lastDividendDate': 1599004800, 'morni ...

# %%
hist
# Out:
#                   Open        High         Low       Close  Volume  Dividends  \
# Date
# 2015-11-11   84.301350   84.578076   82.348897   82.571815  200500        0.0
# 2015-11-12   84.370540   85.054667   83.025347   83.156021  239400        0.0
# 2015-11-13   81.603292   81.856953   80.519448   80.996033  323200        0.0
# 2015-11-16   80.573252   83.294388   80.396453   83.132965  339700        0.0
# 2015-11-17   83.132957   83.463491   82.102921   82.256660  201200        0.0
# ...                ...         ...         ...         ...     ...        ...
# 2020-11-04   95.650002   96.970001   95.290001   95.980003  157400        0.0
# 2020-11-05   95.830002   96.379997   94.860001   95.480003  154600        0.0
# 2020-11-06   95.169998   95.169998   93.570000   94.209999  144200        0.0
# 2020-11-09  101.550003  106.160004  100.720001  104.519997  243000        0.0
# 2020-11-10  109.000000  109.889999  107.620003  109.599998  117117        0.0
#
#             Stock Splits
# Date
# 2015-11-11             0
# 2015-11-12             0
# 2015-11-13             0
# 2015-11-16             0
# 2015-11-17             0
# ...                  ...
# 2020-11-04             0
# 2020-11-05             0
# 2020-11-06             0
# 2020-11-09             0
# 2020-11-10             0
#
# [1259 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn

# %%
ax = hist['Close'].plot(figsize=(16,9))
ax.set_xlabel("Date")
ax.set_ylabel("Price")
ax.set_title("CEO 5 Year Stock Price")
# Out:
# Text(0.5, 1.0, 'CEO 5 Year Stock Price')

# %%
fig = ax.get_figure()
fig.savefig('output.png')

# %% [markdown]
# https://finance.yahoo.com/quote/CEO/history?p=CEO
#  China National Offshore Oil Corporation (CNOOC)
